# %% [markdown]
# LAB 1 - SZYMON HOLAJN - Data Scientist Toolbox

# %% [markdown]
# ZADANIE 3

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
def function(x):
    return x**2+5

# %%
x1 = np.linspace(-1,1,1000)
x2 = np.linspace(-6,6,1000)
x3 = np.linspace(0,5,1000)
y1 = function(x1)
y2 = function(x2)
y3 = function(x3)

# %%
plt.title("Wykres 1") 
plt.xlabel("x") 
plt.ylabel("y") 
plt.plot(x1,y1) 
plt.show()

# %%
plt.title("Wykres 2") 
plt.xlabel("x") 
plt.ylabel("y") 
plt.plot(x2,y2) 
plt.show()

# %%
plt.title("Wykres 3") 
plt.xlabel("x") 
plt.ylabel("y") 
plt.plot(x3,y3) 
plt.show()

# %%
import pandas as pd

# %% [markdown]
# ZADANIE 4

# %%
dane = [['Fernando', 'Alonso','41','male'], ['Max', 'Verstappen','25','male'], ['Lewis', 'Hamilton','37','male'],['Charles', 'Leclerc','24','male'],['Robert', 'Kubica','37','male']]
df = pd.DataFrame(dane, columns=['name', 'surname','age','sex'])
df
# Out:
#        name     surname age   sex
# 0  Fernando      Alonso  41  male
# 1       Max  Verstappen  25  male
# 2     Lewis    Hamilton  37  male
# 3   Charles     Leclerc  24  male
# 4    Robert      Kubica  37  male

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   surname  5 non-null      object
#  2   age      5 non-null      object
#  3   sex      5 non-null      object
# dtypes: object(4)
# memory usage: 288.0+ bytes

# %%
df.describe()
# Out:
#             name surname age   sex
# count          5       5   5     5
# unique         5       5   4     1
# top     Fernando  Alonso  37  male
# freq           1       1   2     5

# %%
df.head(3)
# Out:
#        name     surname age   sex
# 0  Fernando      Alonso  41  male
# 1       Max  Verstappen  25  male
# 2     Lewis    Hamilton  37  male

# %% [markdown]
# Wnioski:<br>
# 1.Podczas instalacji środowiska wirtualnego "szymonholajn" nie napotkałem żadnych problemów. Zainstalowałem również konieczne biblioteki ukazane w pliku requirements.txt m.in.: ipython, jupyter, matplotlib. <br>
# 2.Następnie utworzyłem lokalne repozytorium i połączyłem je ze zdalnym. Link do mojego repozytorium na githubie: https://github.com/szymonholajn/aibd_szymonholajn.git<br>
# 3.Następnie wykonałem 3 wykresy wykorzystując bibliotekę matplotlib.<br>
# 4.W zadaniu czwartym wykorzystując bibliotekę pandas stworzyłem tabelę zawierającą dane osób. Komenda 'info' zawierała informacje o obiektach, które są w danych miejscach w tabeli i zużycie pamięci. Komenda 'Head' pozwala na wypisanie określonej liczby wierszy w tabeli. Natomiast komenda 'describe' zawiera onformacje o liczbie poszczególnych kolumn.
